# %%
import pandas as pd
import altair as alt
import warnings

# %%
# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Load the dataset
file_path = "Ship_Performance_Dataset.csv"
ship = pd.read_csv(file_path)

# %%
#drops the cell with null values
ship.dropna(axis=1)
# Out:
#             Date       Ship_Type           Engine_Type  \
# 0     04-06-2023  Container Ship  Heavy Fuel Oil (HFO)
# 1     11-06-2023    Fish Carrier         Steam Turbine
# 2     18-06-2023  Container Ship                Diesel
# 3     25-06-2023    Bulk Carrier         Steam Turbine
# 4     02-07-2023    Fish Carrier                Diesel
# ...          ...             ...                   ...
# 2731  02-06-2024          Tanker  Heavy Fuel Oil (HFO)
# 2732  09-06-2024    Bulk Carrier  Heavy Fuel Oil (HFO)
# 2733  16-06-2024  Container Ship         Steam Turbine
# 2734  23-06-2024          Tanker  Heavy Fuel Oil (HFO)
# 2735  30-06-2024    Fish Carrier         Steam Turbine
#
#       Speed_Over_Ground_knots  Engine_Power_kW  Distance_Traveled_nm  \
# 0                   12.597558      2062.983982           1030.943616
# 1                   10.387580      1796.057415           1060.486382
# 2                   20.749747      1648.556685            658.874144
# ...

# %%
#Shows first five rows
ship.head()
# Out:
#          Date       Ship_Type    Route_Type           Engine_Type  \
# 0  04-06-2023  Container Ship           NaN  Heavy Fuel Oil (HFO)
# 1  11-06-2023    Fish Carrier    Short-haul         Steam Turbine
# 2  18-06-2023  Container Ship     Long-haul                Diesel
# 3  25-06-2023    Bulk Carrier  Transoceanic         Steam Turbine
# 4  02-07-2023    Fish Carrier  Transoceanic                Diesel
#
#   Maintenance_Status  Speed_Over_Ground_knots  Engine_Power_kW  \
# 0           Critical                12.597558      2062.983982
# 1               Good                10.387580      1796.057415
# 2               Fair                20.749747      1648.556685
# 3               Fair                21.055102       915.261795
# 4               Fair                13.742777      1089.721803
#
#    Distance_Traveled_nm  Draft_meters Weather_Condition  Cargo_Weight_tons  \
# 0           1030.943616     14.132284          Moderate        1959.017882
# ...

# %%
#It is used to convert ship into a Pandas DataFrame.
df= pd.DataFrame(ship)

# %%
#To plot the bar daigram 
chart = alt.Chart(ship).mark_bar().encode(
    x=alt.X('Ship_Type', title="Types of Ships",
            axis=alt.Axis(labelFontSize=16, titleFontSize=18)),
   y=alt.Y('Operational_Cost_USD', title="Operational Cost",
            axis=alt.Axis(labelFontSize=14, titleFontSize=18)),
    color=('Engine_Type'),
).properties(
    width=600,
    height=500,
)
chart.display()
# Out:
# alt.Chart(...)
